# %% [markdown]
# # Assess the sample reproducibility of two runs of the same sample

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
import numpy as np
import amplotlib
from IPython.display import display, HTML
from __future__ import division, print_function

# %% [markdown]
# ## Call code that loads all data  - using the run command:

# %%
run init_array_data_H7N9.py
# Out:
# /Users/thertz/Dropbox/HertzLab/ArrayData/Influenza/H7N9/06_03_2015/H7N9_06_03_15_arrayData_median.mat

# %% [markdown]
# ## Extract specific data of samples of interest:
# assumes that data in in a arr_df format and index is used to select ptids

# %%
ptid1 = 'Obese_1'
ptid2 = 'Obese_2'

resp_mat=arr_df[arr_df.index.isin([ptid1, ptid2])][ind_dict['SHA_ha']]
ptid_labels = [ptid1, ptid2]

# %% [markdown]
# ## Plot reproducibility plots:

# %%
amplotlib.plot_reproducibility_plots(resp_mat=resp_mat, ptid_labels=[ptid1, ptid2], subplot_flag=False,
                                     title_str=False, plot_type='line')
# Out:
# ['Obese_1', 'Obese_2']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a24acf7921c6> in <module>()
#       1 amplotlib.plot_reproducibility_plots(resp_mat=resp_mat, ptid_labels=[ptid1, ptid2], subplot_flag=False,
# ----> 2                                      title_str=False, plot_type='line')
#
# /Users/thertz/Dropbox/HertzLab/Code/Python/utils/amplotlib.pyc in plot_reproducibility_plots(resp_mat, ptid_labels, title_str, subplot_flag, plot_type)
#     186         resp2 = resp_mat[1]
#     187
# --> 188     fig_handles.append(plot_2d_scatter_plot(resp1=resp1, resp2=resp2, labels=ptid_labels, title_str=title_str))
#     189     return fig_handles
#     190
#
# /Users/thertz/Dropbox/HertzLab/Code/Python/utils/amplotlib.pyc in plot_2d_scatter_plot(resp1, resp2, labels, title_str)
#     147         plt.title("r = {:.2f}, p = {:.4f}".format(r, p))
#     148     else:
# --> 149         plt.title(title_str + " r = {:.2f}, p = {:.4f}".format(r, p))
#     150     return f
#     151
#
# TypeError: unsupported operand type(s) for +: 'bool' and 'str'
# /Users/thertz/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
